# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd
import numpy as np

# %% [markdown]
# The Compound score is a metric that calculates the sum of all the lexicon ratings which have been normalized between -1 (most extreme negative) and +1 (most extreme positive).
# positive sentiment : (compound score >= 0.05)
# neutral sentiment : (compound score > -0.05) and (compound score < 0.05)
# negative sentiment : (compound score <= -0.05)

# %%
def calculateCompoundSentiment(sentiment_score):
    # decide sentiment as positive, negative and neutral
    if sentiment_score['compound'] >= 0.05 :
        return "Positive"
 
    elif sentiment_score['compound'] <= -0.05 :
        return "Negative"
 
    else :
        return "Neutral"


def getVaderSentimentScore(sentence):
    analyzer = SentimentIntensityAnalyzer()
    sentiment_score = analyzer.polarity_scores(sentence)
    compoundSentiment = calculateCompoundSentiment(sentiment_score)
    return sentiment_score, compoundSentiment

# %%
data = pd.read_csv("housing_market[datetime.date(2022, 10, 12), datetime.date(2022, 10, 15)]_clean.csv")
data = data.dropna(subset = ['tweet'])
tweetsArr = data['tweet'].to_numpy()
list = []
for tweet in tweetsArr:
    vs = getVaderSentimentScore(tweet)
    list.append(str(vs))
    #data['Compound Sentiment'] = str(vs[1])

# %%
print(list[0])
print(list[1])
print(list[2])
print(list[3])
print(list[4])

data['Sentiment'] = list
data.to_csv('test.csv')
# Out:
# ({'neg': 0.0, 'neu': 0.926, 'pos': 0.074, 'compound': 0.5106}, 'Positive')
# ({'neg': 0.111, 'neu': 0.807, 'pos': 0.082, 'compound': -0.3076}, 'Negative')
# ({'neg': 0.262, 'neu': 0.656, 'pos': 0.082, 'compound': -0.7943}, 'Negative')
# ({'neg': 0.0, 'neu': 0.865, 'pos': 0.135, 'compound': 0.6124}, 'Positive')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')

# %%
# Out:
#            date                                              tweet  \
# 0    2022-10-14     3/ this because it's already been done. fed...
# 1    2022-10-14        right. and those that say the housing ma...
# 2    2022-10-14  almost forgot the interest rate is now over 7%...
# 3    2022-10-14  looking at opening a new short position in asx...
# 4    2022-10-14  this seems to be making the rounds but how abo...
# ..          ...                                                ...
# 104  2022-10-14   my first thought on this is "but we can't fin...
# 105  2022-10-14  for mendonca, berkeley's biggest problem is in...
# 106  2022-10-14   lolol…you need to put your bear market hat on...
# 107  2022-10-14  tornado housing market, ibuying endings, workf...
# 108  2022-10-14  tips for first-time homebuyers [infographic]\r...
#
#             username               location  \
# 0         raspyberry        ontario, canada
# 1     ucomicsandmore                    NaN
# 2      jamescgraves1                    NaN
# 3     putsonbathtime                    NaN
# 4         malifestro                     nw
# ..               ...                    ...
# 104      jakebengenz  saint johns, auckland
# 105     chrissaolson           berkeley, ca
# 106      andrewgraef                    NaN
# 107  realestatebay15              australia
# 108     thepaizgroup                florida
#
#                                            profile bio  likes  retweets  \
# 0                                                  NaN    1.0       0.0
# 1                                                  NaN    1.0       1.0
# 2    vietnam vet (marine infantry), former sports e...    0.0       0.0
# 3    this account is a time capsule of my trades an...    0.0       0.0
# 4                            stock and crypto trading.   53.0      10.0
# ..                                                 ...    ...       ...
# 104  class rules everything around me 🔴⚫️descendant...    0.0       0.0
# 105  i like writing | news reporter for @dailycal |...    0.0       0.0
# 106  primarily here to keep up with financial marke...    0.0       0.0
# 107  we showcase some of the most attractive proper...    0.0       0.0
# 108                            real estate specialists    0.0       0.0
#
#                                              Sentiment
# 0    ({'neg': 0.0, 'neu': 0.926, 'pos': 0.074, 'com...
# 1    ({'neg': 0.111, 'neu': 0.807, 'pos': 0.082, 'c...
# 2    ({'neg': 0.262, 'neu': 0.656, 'pos': 0.082, 'c...
# 3    ({'neg': 0.0, 'neu': 0.865, 'pos': 0.135, 'com...
# 4    ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...
# ..                                                 ...
# 104  ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compoun...
# 105  ({'neg': 0.101, 'neu': 0.899, 'pos': 0.0, 'com...
# 106  ({'neg': 0.166, 'neu': 0.801, 'pos': 0.033, 'c...
# 107  ({'neg': 0.107, 'neu': 0.791, 'pos': 0.102, 'c...
# 108  ({'neg': 0.047, 'neu': 0.923, 'pos': 0.029, 'c...
#
# [100 rows x 8 columns]
