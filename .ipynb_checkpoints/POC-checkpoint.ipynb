# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd
import numpy as np

# %% [markdown]
# The Compound score is a metric that calculates the sum of all the lexicon ratings which have been normalized between -1 (most extreme negative) and +1 (most extreme positive).
# positive sentiment : (compound score >= 0.05)
# neutral sentiment : (compound score > -0.05) and (compound score < 0.05)
# negative sentiment : (compound score <= -0.05)

# %%
def calculateCompoundSentiment(sentiment_score):
    # decide sentiment as positive, negative and neutral
    if sentiment_score['compound'] >= 0.05 :
        return "Positive"
 
    elif sentiment_score['compound'] <= - 0.05 :
        return "Negative"
 
    else :
        return "Neutral"


def getVaderSentimentScore(sentence):
    analyzer = SentimentIntensityAnalyzer()
    sentiment_score = analyzer.polarity_scores(sentence)
    compoundSentiment = calculateCompoundSentiment(sentiment_score)
    return sentiment_score, compoundSentiment

# %%
data = pd.read_csv("housing_market[datetime.date(2022, 10, 12), datetime.date(2022, 10, 15)]_clean.csv")
tweetsArr = data['Tweet'].to_numpy()
list = []
for tweet in tweetsArr:
    vs = getVaderSentimentScore(tweet)
    list.append(vs)
    #data['Compound Sentiment'] = str(vs[1])

#data.to_csv('test.csv')

# %%
print(list[0])
print(list[0][0])
print(list[0][1])

for i in list:
   print(i)
data.to_csv('test.csv')
# Out:
# ({'neg': 0.265, 'neu': 0.686, 'pos': 0.049, 'compound': -0.9382}, 'Negative')
# {'neg': 0.265, 'neu': 0.686, 'pos': 0.049, 'compound': -0.9382}
# Negative
# ({'neg': 0.265, 'neu': 0.686, 'pos': 0.049, 'compound': -0.9382}, 'Negative')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.16, 'neu': 0.538, 'pos': 0.302, 'compound': 0.9136}, 'Positive')
# ({'neg': 0.14, 'neu': 0.763, 'pos': 0.097, 'compound': -0.3612}, 'Negative')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.0, 'neu': 0.943, 'pos': 0.057, 'compound': 0.2023}, 'Positive')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.137, 'neu': 0.792, 'pos': 0.071, 'compound': -0.5109}, 'Negative')
# ({'neg': 0.203, 'neu': 0.797, 'pos': 0.0, 'compound': -0.8807}, 'Negative')
# ({'neg': 0.079, 'neu': 0.684, 'pos': 0.238, 'compound': 0.8422}, 'Positive')
# ({'neg': 0.1, 'neu': 0.802, 'pos': 0.097, 'compound': -0.0258}, 'Neutral')
# ({'neg': 0.163, 'neu': 0.837, 'pos': 0.0, 'compound': -0.5719}, 'Negative')
# ({'neg': 0.128, 'neu': 0.822, 'pos': 0.05, 'compound': -0.4819}, 'Negative')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.0, 'neu': 0.865, 'pos': 0.135, 'compound': 0.1027}, 'Positive')
# ({'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'compound': 0.4019}, 'Positive')
# ({'neg': 0.0, 'neu': 0.855, 'pos': 0.145, 'compound': 0.1779}, 'Positive')
# ({'neg': 0.263, 'neu': 0.688, 'pos': 0.049, 'compound': -0.9158}, 'Negative')
# ({'neg': 0.281, 'neu': 0.719, 'pos': 0.0, 'compound': -0.7783}, 'Negative')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.07, 'neu': 0.766, 'pos': 0.163, 'compound': 0.5393}, 'Positive')
# ({'neg': 0.18, 'neu': 0.726, 'pos': 0.094, 'compound': -0.6908}, 'Negative')
# ({'neg': 0.0, 'neu': 0.884, 'pos': 0.116, 'compound': 0.4404}, 'Positive')
# ({'neg': 0.2, 'neu': 0.8, 'pos': 0.0, 'compound': -0.128}, 'Negative')
# ({'neg': 0.097, 'neu': 0.844, 'pos': 0.06, 'compound': -0.2003}, 'Negative')
# ({'neg': 0.243, 'neu': 0.68, 'pos': 0.077, 'compound': -0.8834}, 'Negative')
# ({'neg': 0.0, 'neu': 0.777, 'pos': 0.223, 'compound': 0.8627}, 'Positive')
# ({'neg': 0.085, 'neu': 0.706, 'pos': 0.21, 'compound': 0.4614}, 'Positive')
# ({'neg': 0.0, 'neu': 0.749, 'pos': 0.251, 'compound': 0.5702}, 'Positive')
# ({'neg': 0.045, 'neu': 0.839, 'pos': 0.117, 'compound': 0.5803}, 'Positive')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.124, 'neu': 0.756, 'pos': 0.12, 'compound': -0.024}, 'Neutral')
# ({'neg': 0.308, 'neu': 0.692, 'pos': 0.0, 'compound': -0.7845}, 'Negative')
# ({'neg': 0.116, 'neu': 0.884, 'pos': 0.0, 'compound': -0.2732}, 'Negative')
# ({'neg': 0.073, 'neu': 0.816, 'pos': 0.112, 'compound': 0.3169}, 'Positive')
# ({'neg': 0.056, 'neu': 0.659, 'pos': 0.285, 'compound': 0.8268}, 'Positive')
# ({'neg': 0.317, 'neu': 0.621, 'pos': 0.062, 'compound': -0.9062}, 'Negative')
# ({'neg': 0.319, 'neu': 0.681, 'pos': 0.0, 'compound': -0.7845}, 'Negative')
# ({'neg': 0.107, 'neu': 0.741, 'pos': 0.151, 'compound': 0.1696}, 'Positive')
# ({'neg': 0.093, 'neu': 0.907, 'pos': 0.0, 'compound': -0.5106}, 'Negative')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.034, 'neu': 0.879, 'pos': 0.087, 'compound': 0.4871}, 'Positive')
# ({'neg': 0.119, 'neu': 0.806, 'pos': 0.075, 'compound': -0.3597}, 'Negative')
# ({'neg': 0.129, 'neu': 0.824, 'pos': 0.047, 'compound': -0.6588}, 'Negative')
# ({'neg': 0.135, 'neu': 0.751, 'pos': 0.114, 'compound': -0.3129}, 'Negative')
# ({'neg': 0.056, 'neu': 0.875, 'pos': 0.069, 'compound': 0.1779}, 'Positive')
# ({'neg': 0.061, 'neu': 0.818, 'pos': 0.122, 'compound': 0.3314}, 'Positive')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.235, 'neu': 0.637, 'pos': 0.128, 'compound': -0.7579}, 'Negative')
# ({'neg': 0.111, 'neu': 0.889, 'pos': 0.0, 'compound': -0.6124}, 'Negative')
# ({'neg': 0.13, 'neu': 0.87, 'pos': 0.0, 'compound': -0.6573}, 'Negative')
# ({'neg': 0.194, 'neu': 0.806, 'pos': 0.0, 'compound': -0.8625}, 'Negative')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'compound': 0.4019}, 'Positive')
# ({'neg': 0.11, 'neu': 0.762, 'pos': 0.128, 'compound': 0.18}, 'Positive')
# ({'neg': 0.079, 'neu': 0.711, 'pos': 0.21, 'compound': 0.8651}, 'Positive')
# ({'neg': 0.22, 'neu': 0.702, 'pos': 0.078, 'compound': -0.7423}, 'Negative')
# ({'neg': 0.114, 'neu': 0.76, 'pos': 0.126, 'compound': 0.4109}, 'Positive')
# ({'neg': 0.0, 'neu': 0.822, 'pos': 0.178, 'compound': 0.6201}, 'Positive')
# ({'neg': 0.174, 'neu': 0.715, 'pos': 0.111, 'compound': -0.4678}, 'Negative')
# ({'neg': 0.0, 'neu': 0.896, 'pos': 0.104, 'compound': 0.4404}, 'Positive')
# ({'neg': 0.06, 'neu': 0.814, 'pos': 0.126, 'compound': 0.5267}, 'Positive')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.0, 'neu': 0.968, 'pos': 0.032, 'compound': 0.1027}, 'Positive')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.167, 'neu': 0.833, 'pos': 0.0, 'compound': -0.296}, 'Negative')
# ({'neg': 0.248, 'neu': 0.693, 'pos': 0.059, 'compound': -0.8569}, 'Negative')
# ({'neg': 0.089, 'neu': 0.829, 'pos': 0.083, 'compound': -0.0498}, 'Neutral')
# ({'neg': 0.0, 'neu': 0.857, 'pos': 0.143, 'compound': 0.3612}, 'Positive')
# ({'neg': 0.145, 'neu': 0.855, 'pos': 0.0, 'compound': -0.4391}, 'Negative')
# ({'neg': 0.161, 'neu': 0.749, 'pos': 0.089, 'compound': -0.3612}, 'Negative')
# ({'neg': 0.094, 'neu': 0.906, 'pos': 0.0, 'compound': -0.5927}, 'Negative')
# ({'neg': 0.122, 'neu': 0.878, 'pos': 0.0, 'compound': -0.69}, 'Negative')
# ({'neg': 0.258, 'neu': 0.742, 'pos': 0.0, 'compound': -0.8555}, 'Negative')
# ({'neg': 0.0, 'neu': 0.929, 'pos': 0.071, 'compound': 0.3182}, 'Positive')
# ({'neg': 0.049, 'neu': 0.951, 'pos': 0.0, 'compound': -0.3662}, 'Negative')
# ({'neg': 0.0, 'neu': 0.674, 'pos': 0.326, 'compound': 0.4404}, 'Positive')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.0, 'neu': 0.839, 'pos': 0.161, 'compound': 0.3612}, 'Positive')
# ({'neg': 0.156, 'neu': 0.662, 'pos': 0.182, 'compound': 0.2732}, 'Positive')
# ({'neg': 0.26, 'neu': 0.74, 'pos': 0.0, 'compound': -0.7964}, 'Negative')
# ({'neg': 0.233, 'neu': 0.767, 'pos': 0.0, 'compound': -0.802}, 'Negative')
# ({'neg': 0.111, 'neu': 0.889, 'pos': 0.0, 'compound': -0.3089}, 'Negative')
# ({'neg': 0.159, 'neu': 0.767, 'pos': 0.075, 'compound': -0.4301}, 'Negative')
# ({'neg': 0.153, 'neu': 0.796, 'pos': 0.051, 'compound': -0.5542}, 'Negative')
# ({'neg': 0.151, 'neu': 0.849, 'pos': 0.0, 'compound': -0.6879}, 'Negative')
# ({'neg': 0.0, 'neu': 0.924, 'pos': 0.076, 'compound': 0.4919}, 'Positive')
# ({'neg': 0.171, 'neu': 0.753, 'pos': 0.076, 'compound': -0.4832}, 'Negative')
# ({'neg': 0.19, 'neu': 0.81, 'pos': 0.0, 'compound': -0.6573}, 'Negative')
# ({'neg': 0.19, 'neu': 0.81, 'pos': 0.0, 'compound': -0.6573}, 'Negative')
# ({'neg': 0.19, 'neu': 0.81, 'pos': 0.0, 'compound': -0.6573}, 'Negative')
# ({'neg': 0.19, 'neu': 0.81, 'pos': 0.0, 'compound': -0.6573}, 'Negative')
# ({'neg': 0.196, 'neu': 0.804, 'pos': 0.0, 'compound': -0.763}, 'Negative')
# ({'neg': 0.0, 'neu': 0.908, 'pos': 0.092, 'compound': 0.5362}, 'Positive')
# ({'neg': 0.1, 'neu': 0.756, 'pos': 0.145, 'compound': 0.168}, 'Positive')
# ({'neg': 0.218, 'neu': 0.732, 'pos': 0.051, 'compound': -0.8625}, 'Negative')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.0, 'neu': 0.921, 'pos': 0.079, 'compound': 0.2263}, 'Positive')
# ({'neg': 0.11, 'neu': 0.833, 'pos': 0.056, 'compound': -0.4588}, 'Negative')
# ({'neg': 0.116, 'neu': 0.884, 'pos': 0.0, 'compound': -0.2732}, 'Negative')
# ({'neg': 0.03, 'neu': 0.746, 'pos': 0.225, 'compound': 0.8573}, 'Positive')
# ({'neg': 0.166, 'neu': 0.7, 'pos': 0.134, 'compound': -0.2732}, 'Negative')
# ({'neg': 0.196, 'neu': 0.736, 'pos': 0.068, 'compound': -0.696}, 'Negative')
# ({'neg': 0.119, 'neu': 0.731, 'pos': 0.15, 'compound': 0.2006}, 'Positive')
# ({'neg': 0.0, 'neu': 0.85, 'pos': 0.15, 'compound': 0.6956}, 'Positive')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.151, 'neu': 0.692, 'pos': 0.157, 'compound': 0.0258}, 'Neutral')
# ({'neg': 0.072, 'neu': 0.749, 'pos': 0.179, 'compound': 0.5106}, 'Positive')
# ({'neg': 0.082, 'neu': 0.782, 'pos': 0.135, 'compound': 0.3612}, 'Positive')
# ({'neg': 0.0, 'neu': 0.581, 'pos': 0.419, 'compound': 0.7579}, 'Positive')
# ({'neg': 0.064, 'neu': 0.797, 'pos': 0.14, 'compound': 0.51}, 'Positive')
# ({'neg': 0.08, 'neu': 0.646, 'pos': 0.274, 'compound': 0.836}, 'Positive')
# ({'neg': 0.039, 'neu': 0.81, 'pos': 0.151, 'compound': 0.6124}, 'Positive')
# ({'neg': 0.026, 'neu': 0.824, 'pos': 0.15, 'compound': 0.6908}, 'Positive')
# ({'neg': 0.152, 'neu': 0.747, 'pos': 0.102, 'compound': -0.296}, 'Negative')
# ({'neg': 0.027, 'neu': 0.882, 'pos': 0.09, 'compound': 0.4939}, 'Positive')
# ({'neg': 0.079, 'neu': 0.794, 'pos': 0.127, 'compound': 0.4215}, 'Positive')
# ({'neg': 0.062, 'neu': 0.739, 'pos': 0.199, 'compound': 0.8398}, 'Positive')
# ({'neg': 0.135, 'neu': 0.736, 'pos': 0.129, 'compound': -0.0258}, 'Neutral')
# ({'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compound': 0.6437}, 'Positive')
# ({'neg': 0.042, 'neu': 0.792, 'pos': 0.166, 'compound': 0.743}, 'Positive')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.07, 'neu': 0.892, 'pos': 0.038, 'compound': -0.25}, 'Negative')
# ({'neg': 0.028, 'neu': 0.972, 'pos': 0.0, 'compound': -0.0572}, 'Negative')
# ({'neg': 0.0, 'neu': 0.85, 'pos': 0.15, 'compound': 0.1513}, 'Positive')
# ({'neg': 0.268, 'neu': 0.515, 'pos': 0.216, 'compound': -0.128}, 'Negative')
# ({'neg': 0.481, 'neu': 0.486, 'pos': 0.033, 'compound': -0.9843}, 'Negative')
# ({'neg': 0.061, 'neu': 0.939, 'pos': 0.0, 'compound': -0.2263}, 'Negative')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.0, 'neu': 0.93, 'pos': 0.07, 'compound': 0.3612}, 'Positive')
# ({'neg': 0.079, 'neu': 0.826, 'pos': 0.096, 'compound': 0.4127}, 'Positive')
# ({'neg': 0.171, 'neu': 0.732, 'pos': 0.096, 'compound': -0.5994}, 'Negative')
# ({'neg': 0.134, 'neu': 0.804, 'pos': 0.063, 'compound': -0.3382}, 'Negative')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.116, 'neu': 0.884, 'pos': 0.0, 'compound': -0.2732}, 'Negative')
# ({'neg': 0.105, 'neu': 0.691, 'pos': 0.204, 'compound': 0.7184}, 'Positive')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.0, 'neu': 0.884, 'pos': 0.116, 'compound': 0.2732}, 'Positive')
# ({'neg': 0.171, 'neu': 0.691, 'pos': 0.138, 'compound': -0.3818}, 'Negative')
# ({'neg': 0.125, 'neu': 0.804, 'pos': 0.071, 'compound': -0.296}, 'Negative')
# ({'neg': 0.121, 'neu': 0.879, 'pos': 0.0, 'compound': -0.296}, 'Negative')
# ({'neg': 0.0, 'neu': 0.801, 'pos': 0.199, 'compound': 0.4101}, 'Positive')
# ({'neg': 0.138, 'neu': 0.778, 'pos': 0.084, 'compound': -0.5859}, 'Negative')
# ({'neg': 0.043, 'neu': 0.957, 'pos': 0.0, 'compound': -0.2462}, 'Negative')
# ({'neg': 0.132, 'neu': 0.719, 'pos': 0.15, 'compound': 0.0772}, 'Positive')
# ({'neg': 0.414, 'neu': 0.586, 'pos': 0.0, 'compound': -0.9001}, 'Negative')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.261, 'neu': 0.739, 'pos': 0.0, 'compound': -0.8126}, 'Negative')
# ({'neg': 0.049, 'neu': 0.951, 'pos': 0.0, 'compound': -0.128}, 'Negative')
# ({'neg': 0.046, 'neu': 0.552, 'pos': 0.402, 'compound': 0.9493}, 'Positive')
# ({'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'compound': 0.5719}, 'Positive')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.116, 'neu': 0.884, 'pos': 0.0, 'compound': -0.2732}, 'Negative')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.174, 'neu': 0.612, 'pos': 0.213, 'compound': 0.3138}, 'Positive')
# ({'neg': 0.118, 'neu': 0.755, 'pos': 0.127, 'compound': -0.1779}, 'Negative')
# ({'neg': 0.04, 'neu': 0.87, 'pos': 0.09, 'compound': 0.3989}, 'Positive')
# ({'neg': 0.0, 'neu': 0.798, 'pos': 0.202, 'compound': 0.4199}, 'Positive')
# ({'neg': 0.105, 'neu': 0.866, 'pos': 0.03, 'compound': -0.3716}, 'Negative')
# ({'neg': 0.107, 'neu': 0.61, 'pos': 0.284, 'compound': 0.8872}, 'Positive')
# ({'neg': 0.0, 'neu': 0.927, 'pos': 0.073, 'compound': 0.5267}, 'Positive')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.149, 'neu': 0.851, 'pos': 0.0, 'compound': -0.5423}, 'Negative')
# ({'neg': 0.03, 'neu': 0.75, 'pos': 0.22, 'compound': 0.7667}, 'Positive')
# ({'neg': 0.044, 'neu': 0.886, 'pos': 0.069, 'compound': 0.3409}, 'Positive')
# ({'neg': 0.086, 'neu': 0.859, 'pos': 0.056, 'compound': -0.296}, 'Negative')
# ({'neg': 0.118, 'neu': 0.882, 'pos': 0.0, 'compound': -0.7003}, 'Negative')
# ({'neg': 0.336, 'neu': 0.664, 'pos': 0.0, 'compound': -0.7644}, 'Negative')
# ({'neg': 0.104, 'neu': 0.896, 'pos': 0.0, 'compound': -0.296}, 'Negative')
# ({'neg': 0.201, 'neu': 0.584, 'pos': 0.214, 'compound': -0.1508}, 'Negative')
# ({'neg': 0.0, 'neu': 0.896, 'pos': 0.104, 'compound': 0.2732}, 'Positive')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.188, 'neu': 0.625, 'pos': 0.188, 'compound': -0.0}, 'Neutral')
# ({'neg': 0.23, 'neu': 0.552, 'pos': 0.218, 'compound': -0.1027}, 'Negative')
# ({'neg': 0.0, 'neu': 0.861, 'pos': 0.139, 'compound': 0.4404}, 'Positive')
# ({'neg': 0.264, 'neu': 0.736, 'pos': 0.0, 'compound': -0.9378}, 'Negative')
# ({'neg': 0.034, 'neu': 0.865, 'pos': 0.101, 'compound': 0.4939}, 'Positive')
# ({'neg': 0.0, 'neu': 0.932, 'pos': 0.068, 'compound': 0.4019}, 'Positive')
# ({'neg': 0.131, 'neu': 0.841, 'pos': 0.029, 'compound': -0.6808}, 'Negative')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.0, 'neu': 0.826, 'pos': 0.174, 'compound': 0.2732}, 'Positive')
# ({'neg': 0.158, 'neu': 0.842, 'pos': 0.0, 'compound': -0.8038}, 'Negative')
# ({'neg': 0.266, 'neu': 0.734, 'pos': 0.0, 'compound': -0.8225}, 'Negative')
# ({'neg': 0.125, 'neu': 0.804, 'pos': 0.071, 'compound': -0.296}, 'Negative')
# ({'neg': 0.0, 'neu': 0.848, 'pos': 0.152, 'compound': 0.6369}, 'Positive')
# ({'neg': 0.0, 'neu': 0.676, 'pos': 0.324, 'compound': 0.8225}, 'Positive')
# ({'neg': 0.244, 'neu': 0.756, 'pos': 0.0, 'compound': -0.9313}, 'Negative')
# ({'neg': 0.214, 'neu': 0.786, 'pos': 0.0, 'compound': -0.8777}, 'Negative')
# ({'neg': 0.184, 'neu': 0.816, 'pos': 0.0, 'compound': -0.7269}, 'Negative')
# ({'neg': 0.15, 'neu': 0.769, 'pos': 0.081, 'compound': -0.2023}, 'Negative')
# ({'neg': 0.161, 'neu': 0.839, 'pos': 0.0, 'compound': -0.8625}, 'Negative')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.034, 'neu': 0.85, 'pos': 0.116, 'compound': 0.6597}, 'Positive')
# ({'neg': 0.0, 'neu': 0.89, 'pos': 0.11, 'compound': 0.2732}, 'Positive')
# ({'neg': 0.075, 'neu': 0.925, 'pos': 0.0, 'compound': -0.4767}, 'Negative')
# ({'neg': 0.039, 'neu': 0.903, 'pos': 0.058, 'compound': 0.2023}, 'Positive')
# ({'neg': 0.0, 'neu': 0.933, 'pos': 0.067, 'compound': 0.4767}, 'Positive')
# ({'neg': 0.121, 'neu': 0.828, 'pos': 0.051, 'compound': -0.4767}, 'Negative')
# ({'neg': 0.124, 'neu': 0.694, 'pos': 0.182, 'compound': 0.3612}, 'Positive')
# ({'neg': 0.161, 'neu': 0.839, 'pos': 0.0, 'compound': -0.8625}, 'Negative')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.093, 'neu': 0.907, 'pos': 0.0, 'compound': -0.4588}, 'Negative')
# ({'neg': 0.229, 'neu': 0.771, 'pos': 0.0, 'compound': -0.9509}, 'Negative')
# ({'neg': 0.049, 'neu': 0.951, 'pos': 0.0, 'compound': -0.2732}, 'Negative')
# ({'neg': 0.131, 'neu': 0.808, 'pos': 0.061, 'compound': -0.5282}, 'Negative')
# ({'neg': 0.051, 'neu': 0.892, 'pos': 0.057, 'compound': 0.0757}, 'Positive')
# ({'neg': 0.0, 'neu': 0.784, 'pos': 0.216, 'compound': 0.836}, 'Positive')
# ({'neg': 0.0, 'neu': 0.86, 'pos': 0.14, 'compound': 0.4753}, 'Positive')
# ({'neg': 0.066, 'neu': 0.876, 'pos': 0.058, 'compound': -0.1027}, 'Negative')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.154, 'neu': 0.846, 'pos': 0.0, 'compound': -0.25}, 'Negative')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.236, 'neu': 0.66, 'pos': 0.104, 'compound': -0.5859}, 'Negative')
# ({'neg': 0.126, 'neu': 0.63, 'pos': 0.244, 'compound': 0.6705}, 'Positive')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.0, 'neu': 0.925, 'pos': 0.075, 'compound': 0.2732}, 'Positive')
# ({'neg': 0.151, 'neu': 0.795, 'pos': 0.054, 'compound': -0.5859}, 'Negative')
# ({'neg': 0.2, 'neu': 0.8, 'pos': 0.0, 'compound': -0.4588}, 'Negative')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.07, 'neu': 0.93, 'pos': 0.0, 'compound': -0.4314}, 'Negative')
# ({'neg': 0.066, 'neu': 0.934, 'pos': 0.0, 'compound': -0.1779}, 'Negative')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'compound': 0.6124}, 'Positive')
# ({'neg': 0.106, 'neu': 0.788, 'pos': 0.106, 'compound': 0.2465}, 'Positive')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.176, 'neu': 0.757, 'pos': 0.068, 'compound': -0.6124}, 'Negative')
# ({'neg': 0.135, 'neu': 0.637, 'pos': 0.228, 'compound': 0.3612}, 'Positive')
# ({'neg': 0.0, 'neu': 0.915, 'pos': 0.085, 'compound': 0.0772}, 'Positive')
# ({'neg': 0.035, 'neu': 0.775, 'pos': 0.191, 'compound': 0.7684}, 'Positive')
# ({'neg': 0.093, 'neu': 0.712, 'pos': 0.195, 'compound': 0.722}, 'Positive')
# ({'neg': 0.214, 'neu': 0.714, 'pos': 0.071, 'compound': -0.5859}, 'Negative')
# ({'neg': 0.108, 'neu': 0.826, 'pos': 0.066, 'compound': -0.3612}, 'Negative')
# ({'neg': 0.0, 'neu': 0.937, 'pos': 0.063, 'compound': 0.3182}, 'Positive')
# ({'neg': 0.076, 'neu': 0.714, 'pos': 0.21, 'compound': 0.8705}, 'Positive')
# ({'neg': 0.052, 'neu': 0.903, 'pos': 0.045, 'compound': -0.0772}, 'Negative')
# ({'neg': 0.078, 'neu': 0.819, 'pos': 0.103, 'compound': 0.1779}, 'Positive')
# ({'neg': 0.119, 'neu': 0.806, 'pos': 0.075, 'compound': -0.296}, 'Negative')
# ({'neg': 0.0, 'neu': 0.745, 'pos': 0.255, 'compound': 0.7351}, 'Positive')
# ({'neg': 0.108, 'neu': 0.734, 'pos': 0.158, 'compound': 0.0772}, 'Positive')
# ({'neg': 0.128, 'neu': 0.74, 'pos': 0.132, 'compound': 0.319}, 'Positive')
# ({'neg': 0.121, 'neu': 0.81, 'pos': 0.069, 'compound': -0.1531}, 'Negative')
# ({'neg': 0.033, 'neu': 0.698, 'pos': 0.269, 'compound': 0.8962}, 'Positive')
# ({'neg': 0.174, 'neu': 0.725, 'pos': 0.101, 'compound': -0.5106}, 'Negative')
# ({'neg': 0.104, 'neu': 0.896, 'pos': 0.0, 'compound': -0.5574}, 'Negative')
# ({'neg': 0.072, 'neu': 0.684, 'pos': 0.244, 'compound': 0.8968}, 'Positive')
# ({'neg': 0.182, 'neu': 0.656, 'pos': 0.162, 'compound': -0.0829}, 'Negative')
# ({'neg': 0.208, 'neu': 0.731, 'pos': 0.061, 'compound': -0.6124}, 'Negative')
# ({'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'compound': 0.5719}, 'Positive')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.069, 'neu': 0.755, 'pos': 0.176, 'compound': 0.6249}, 'Positive')
# ({'neg': 0.025, 'neu': 0.715, 'pos': 0.259, 'compound': 0.9287}, 'Positive')
# ({'neg': 0.0, 'neu': 0.793, 'pos': 0.207, 'compound': 0.7845}, 'Positive')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.059, 'neu': 0.811, 'pos': 0.13, 'compound': 0.5916}, 'Positive')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.0, 'neu': 0.811, 'pos': 0.189, 'compound': 0.2732}, 'Positive')
# ({'neg': 0.0, 'neu': 0.811, 'pos': 0.189, 'compound': 0.2732}, 'Positive')
# ({'neg': 0.119, 'neu': 0.881, 'pos': 0.0, 'compound': -0.4767}, 'Negative')
# ({'neg': 0.153, 'neu': 0.678, 'pos': 0.169, 'compound': 0.0624}, 'Positive')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.177, 'neu': 0.726, 'pos': 0.097, 'compound': -0.8225}, 'Negative')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'compound': 0.5653}, 'Positive')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.032, 'neu': 0.909, 'pos': 0.058, 'compound': 0.296}, 'Positive')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.0, 'neu': 0.788, 'pos': 0.212, 'compound': 0.8271}, 'Positive')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.346, 'neu': 0.619, 'pos': 0.035, 'compound': -0.9194}, 'Negative')
# ({'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'Neutral')
# ({'neg': 0.0, 'neu': 0.783, 'pos': 0.217, 'compound': 0.8271}, 'Positive')
# ({'neg': 0.103, 'neu': 0.856, 'pos': 0.041, 'compound': -0.4939}, 'Negative')
